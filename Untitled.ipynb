# %%
import pandas as pd 
data = pd.read_csv("tottus.csv")
data[['category', 'subcate', 'NAME', 'UNIDAD', 'PRECIO', 'PREC']]
# Out:
#          category                                   subcate  \
# 0    Más Verduras  Ensaladas y Verduras Empacadas / Picadas
# 1    Más Verduras  Ensaladas y Verduras Empacadas / Picadas
# 2      Más Frutas               Frutos Secos y Otros Snacks
# 3        Verduras         Papas, Camotes y otros Tubérculos
# 4     Mundo Chino                                 Ver todas
# ..            ...                                       ...
# 186      Verduras            Cebollas, Ajos y otros Básicos
# 187        Frutas        Manzanas, Plátanos y otros Básicos
# 188        Frutas        Limones, Naranjas y otros Cítricos
# 189      Verduras                            Setas y Hongos
# 190   Mundo Chino                             Verdura China
#
#                                                   NAME               UNIDAD  \
# 0    Verduras para Arroz con Pollo   \n\t\t\t\t\t\t...        Envase x 200g
# 1              Rabanito   \n\t\t\t\t\t\t\t\t\t\tTOTTUS  600g es aprox. 10un
# ...
